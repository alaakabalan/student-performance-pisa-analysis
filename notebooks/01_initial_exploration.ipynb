# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
df=pd.read_excel('../data/Maths.xlsx')

# First few rows
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
# Overview of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      397 non-null    object
#  1   sex         397 non-null    object
#  2   age         397 non-null    int64
#  3   address     397 non-null    object
#  4   famsize     397 non-null    object
#  5   Pstatus     397 non-null    object
#  6   Medu        397 non-null    int64
#  7   Fedu        397 non-null    int64
#  8   Mjob        397 non-null    object
#  9   Fjob        397 non-null    object
#  10  reason      397 non-null    object
#  11  guardian    397 non-null    object
#  12  traveltime  397 non-null    int64
#  13  studytime   397 non-null    int64
#  14  failures    397 non-null    int64
#  15  schoolsup   397 non-null    object
#  16  famsup      397 non-null    object
#  17  paid        397 non-null    object
#  18  activities  397 non-null    object
# ...

# %%
# Summary statistics
df.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  397.000000  397.000000  397.000000  397.000000  397.000000  397.000000
# mean    16.705290    2.748111    2.521411    1.450882    2.032746    0.335013
# std      1.279716    1.097301    1.090672    0.696840    0.838731    0.742714
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  397.000000  397.000000  397.000000  397.000000  397.000000  397.000000
# mean     3.944584    3.234257    3.108312    1.478589    2.289673    3.556675
# ...

# %%
# Check for missing values
df.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
# All columns
df.columns.tolist()
# Out:
# ['school',
#  'sex',
#  'age',
#  'address',
#  'famsize',
#  'Pstatus',
#  'Medu',
#  'Fedu',
#  'Mjob',
#  'Fjob',
#  'reason',
#  'guardian',
#  'traveltime',
#  'studytime',
#  'failures',
#  'schoolsup',
#  'famsup',
#  'paid',
#  'activities',
#  'nursery',
#  'higher',
#  'internet',
#  'romantic',
#  'famrel',
#  'freetime',
#  'goout',
#  'Dalc',
#  'Walc',
#  'health',
#  'absences',
#  'G1',
#  'G2',
#  'G3']

# %%
# See data types
df.dtypes
# Out:
# school        object
# sex           object
# age            int64
# address       object
# famsize       object
# Pstatus       object
# Medu           int64
# Fedu           int64
# Mjob          object
# Fjob          object
# reason        object
# guardian      object
# traveltime     int64
# studytime      int64
# failures       int64
# schoolsup     object
# famsup        object
# paid          object
# activities    object
# nursery       object
# higher        object
# internet      object
# romantic      object
# famrel         int64
# freetime       int64
# goout          int64
# Dalc           int64
# Walc           int64
# health         int64
# absences       int64
# G1             int64
# G2             int64
# G3             int64
# dtype: object

# %%
# 1. Distribution of final grades (G3)
sns.histplot(df['G3'], bins=15, kde=True)
plt.title('Distribution of final grades (G3)')
plt.show()

# %%
# 2. Average G3 by Gender
sns.boxplot(data=df, x='sex', y='G3')
plt.show()

# %%
# 3. Correlation heatmap
plt.figure(figsize=(14,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
# Do final grades differe with genders?
plt.figure(figsize=(8, 4))
sns.boxplot(data=df, x='sex', y='G3')
plt.title(' Final grade by gender')
plt.xlabel('sex')
plt.ylabel('G3')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.groupby("sex")['G3'].mean()
# Out:
# sex
# F     9.947368
# M    10.856383
# Name: G3, dtype: float64

# %% [markdown]
# ### Insight: Gender and Performance
# On average, male students scored slightly higher than female students in their final Math grade.

# %%
plt.figure(figsize=(8, 5))
sns.histplot(data=df, x='G3', hue='sex', kde=True, bins=15)
plt.title('Grade distribution by gender')
plt.xlabel('Final grade')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.violinplot(data=df, x="sex", y="G3", palette="Pastel1")
plt.title("Distribution of Final Grades by Gender")
plt.xlabel("Gender")
plt.ylabel("Final Grade (G3)")
plt.show()
# Out:
# C:\Users\alaak\AppData\Local\Temp\ipykernel_6092\228778797.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x="sex", y="G3", palette="Pastel1")

# %%
sns.countplot(data=df, x='G3', hue='sex')
plt.title("Count of Grades by Gender")
plt.show()

# %%
# Does alcohol use affect the final grade?
df['avg_alcohol']=(df['Dalc']+df['Walc'])/2
plt.figure(figsize=(6, 4))
sns.scatterplot(data=df, x='avg_alcohol', y='G3', hue='sex')
plt.title('Final grade vs Average alcohol use')
plt.xlabel('Average alcohol use (1:low , 5:high)')
plt.ylabel('Final grade')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(data=df, x='avg_alcohol', y='G3')
plt.title('Final grade distr. by avg alcohol use')
plt.xlabel('Average alcohol use, 1:low 5:high')
plt.ylabel('G3')
plt.show()

# %% [markdown]
# ### Insight: Does alcohol use affect performance and final grade?
# The boxplot suggests that students who consume less alcohol tend to perform better. Higher levels of alcohol use are associated with a wider range of lower final grades, indicating a potential negative effect on academic achievement.

# %%
import numpy as np
plt.figure(figsize=(8, 5))
sns.barplot(data=df, x='Medu', y='G3', estimator=np.mean, errorbar='sd')
plt.title('Mother education vs Final grade')
plt.xlabel('Mother education')
plt.ylabel('Final grade G3')
plt.show()

# %%
plt.Figure(figsize=(6, 4))
sns.barplot(data=df, x='Fedu', y='G3', estimator=np.mean, errorbar='sd')
plt.title('Fathers education vs Average final grade')
plt.xlabel('Father education')
plt.ylabel('Final grade')
plt.show()

# %%
df['avg_parent_edu']=(df['Medu']+df['Fedu'])/2
plt.figure(figsize=(6, 4))
sns.boxplot(data=df, x='avg_parent_edu', y='G3')
plt.title('Average parent education vs Final grade')
plt.xlabel('Average parents education 0=low 4=high')
plt.ylabel('Final grade G3')
plt.show()

# %%
sns.boxplot(data=df, x='studytime', y='G3', hue='sex')
plt.title("Final grades by Study Time and Gender")
plt.show()

# %%
sns.scatterplot(data=df, x='absences', y='G3', hue='sex')
plt.title('Final grade vs Number of absences')
plt.xlabel('Absences')
plt.ylabel('Final Grade')
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.boxplot(data=df, x='internet', y='G3')
plt.title("Final Grade by Internet Access")
plt.xlabel("Internet Access (yes/no)")
plt.ylabel("Final Grade (G3)")
plt.show()

# %% [markdown]
# # This shows that students with internet access at home tend to have higher final grade.
